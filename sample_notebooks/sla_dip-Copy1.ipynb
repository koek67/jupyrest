# %% [markdown]
# # SLA Dip Runbook
#
# This runbook identifies a customer whose SLA is at risk of violation.

# %%
from jupyrest.helpers import Customer, SLADip, save_graph, get_customer, get_past_incident_ids, get_graph
from datetime import datetime

# %%
# Default parameters
customer_id = "xxx"
incident_time = "xxx"
incident_id = "xxx"

# %%
# Parameters
customer_id = "Paddys_Pub"
incident_time = "2022-01-01T00:04:00"
incident_id = "005"

# %% [markdown]
# Annotate the affected customer with the SLA dip information.

# %%
customer = get_customer(customer_id)
sla_dip = SLADip(incident_id=incident_id, incident_time=datetime.fromisoformat(incident_time), customer=customer)

# %%
from jupyrest.graph import visualize, create_graph

# %%
g = create_graph(sla_dip)

# %%
incident_ids = get_past_incident_ids()
print(f"Found previous incidents {incident_ids}")
g = g + get_graph(*incident_ids)
# Out:
# Found previous incidents ['001', '002', '003', '004']

# %%
visualize(g)

# %%
g1 = get_graph('002')
visualize(g1)
g1.serialize("yello.ttl")
# Out:
# <Graph identifier=N53325f80b5c14344bc5f81a2ee978a36 (<class 'rdflib.graph.Graph'>)>

# %%
save_graph(sla_dip, g)

# %%
from cog.torque import Graph

# %%
g1 = Graph("incident005")

# %%
g

# %%
from rdflib import Graph as rdfGraph

rdfGraph().parse("/home/koushikkrishnan/.jupyrest_graphs/005.ttl").serialize(destination="/home/koushikkrishnan/.jupyrest_graphs/005.nt")
# Out:
# <Graph identifier=N825e2ce9fe554f7fbab16be4a0d65861 (<class 'rdflib.graph.Graph'>)>

# %%
g.load_triples("/home/koushikkrishnan/.jupyrest_graphs/005.nt")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_61910/2226159938.py in <cell line: 1>()
# ----> 1 g.load_triples("/home/koushikkrishnan/.jupyrest_graphs/005.nt")
#
# ~/code/jupyrest/.venv/lib/python3.8/site-packages/cog/torque.py in load_triples(self, graph_data_path, graph_name)
#      77
#      78         graph_name = self.graph_name if graph_name is None else graph_name
# ---> 79         self.cog.load_triples(graph_data_path, graph_name)
#      80         self.all_predicates = self.cog.list_tables()
#      81         return None
#
# ~/code/jupyrest/.venv/lib/python3.8/site-packages/cog/database.py in load_triples(self, graph_data_path, graph_name)
#     298        with open(graph_data_path) as f:
#     299            for line in f:
# --> 300                 subject, predicate, object, context = parse_tripple(line)
#     301                 self.load_table(hash_predicate(predicate), graph_name)
#     302                 self.put_node(subject, predicate, object)
#
# ~/code/jupyrest/.venv/lib/python3.8/site-packages/cog/database.py in parse_tripple(tripple)
#      37 def parse_tripple(tripple):
#      38     tokens = shlex.split(tripple)
# ---> 39     subject = tokens[0].strip()
#      40     predicate = tokens[1].strip()
#      41     object = tokens[2].strip()
#
# IndexError: list index out of range

# %%
from rdflib import Graph
from pathlib import Path

data = Path("/home/koushikkrishnan/.jupyrest_graphs/005.ttl").read_text()
f = Graph()
f.parse(data=data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_93329/38474998.py in <cell line: 4>()
#       2 from pathlib import Path
#       3
# ----> 4 data = Path("/home/koushikkrishnan/.jupyrest_graphs/005.ttl").read_text()
#       5 f = Graph()
#       6 f.parse(data=data)
#
# ~/.pyenv/versions/3.8.13/lib/python3.8/pathlib.py in read_text(self, encoding, errors)
#    1234         Open the file in text mode, read it, and close the file.
#    1235         """
# -> 1236         with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1237             return f.read()
#    1238
#
# ~/.pyenv/versions/3.8.13/lib/python3.8/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1220         if self._closed:
#    1221             self._raise_closed()
# -> 1222         return io.open(self, mode, buffering, encoding, errors, newline,
#    1223                        opener=self._opener)
#    1224
#
# ~/.pyenv/versions/3.8.13/lib/python3.8/pathlib.py in _opener(self, name, flags, mode)
#    1076     def _opener(self, name, flags, mode=0o666):
#    1077         # A stub for the opener argument to built-in open()
# -> 1078         return self._accessor.open(self, flags, mode)
#    1079
#    1080     def _raw_open(self, flags, mode=0o777):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/koushikkrishnan/.jupyrest_graphs/005.ttl'
